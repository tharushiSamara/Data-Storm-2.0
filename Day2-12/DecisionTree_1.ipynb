# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import AdaBoostClassifier

# %%
train = pd.read_csv('F:\Data Storm 2.0\Dataset\Hotel-A-train.csv')
train.head()
# Out:
#    Reservation-id Gender  Age         Ethnicity Educational_Level  \
# 0        39428300      F   40            Latino              Grad
# 1        77491756      F   49            Latino        Mid-School
# 2        73747291      F   42         caucasian              Grad
# 3        67301739      M   25  African American           College
# 4        77222321      F   62            Latino       High-School
#
#         Income Country_region      Hotel_Type Expected_checkin  \
# 0         <25K          North      City Hotel         7/1/2015
# 1  50K -- 100K           East      City Hotel         7/1/2015
# 2         <25K           East      City Hotel         7/2/2015
# 3        >100K          South  Airport Hotels         7/2/2015
# 4    25K --50K           East          Resort         7/3/2015
#
#   Expected_checkout  ... Meal_Type  Visted_Previously  Previous_Cancellations  \
# 0          7/2/2015  ...        BB                 No                      No
# 1          7/2/2015  ...        BB                 No                      No
# 2          7/6/2015  ...        BB                 No                      No
# 3          7/3/2015  ...        BB                 No                      No
# 4          7/4/2015  ...        BB                 No                      No
#
#    Deposit_type Booking_channel Required_Car_Parking Reservation_Status  \
# 0    No Deposit          Online                  Yes           Check-In
# 1    Refundable          Online                  Yes           Check-In
# 2    No Deposit          Online                  Yes           Check-In
# 3    Refundable           Agent                  Yes           Check-In
# 4    No Deposit          Direct                   No           Check-In
#
#   Use_Promotion Discount_Rate Room_Rate
# 0           Yes            10       218
# 1            No             0       185
# 2            No             0       119
# 3           Yes             5       144
# 4           Yes            10       242
#
# [5 rows x 24 columns]

# %%
validate = pd.read_csv('F:\Data Storm 2.0\Dataset\Hotel-A-validation.csv')
validate.head()
# Out:
#    Reservation-id Gender  Age       Ethnicity Educational_Level     Income  \
# 0        45716350      M   56       caucasian              Grad       <25K
# 1        88857401      M   60          Latino           College  25K --50K
# 2        16074440      F   58  Asian American           College       <25K
# 3        10992124      F   23          Latino           College  25K --50K
# 4        15934351      F   47  Asian American           College  25K --50K
#
#   Country_region      Hotel_Type Expected_checkin Expected_checkout  ...  \
# 0           West          Resort        8/31/2016          9/2/2016  ...
# 1           West          Resort        8/31/2016          9/4/2016  ...
# 2          North  Airport Hotels         9/1/2016          9/2/2016  ...
# 3           East  Airport Hotels        8/31/2016          9/2/2016  ...
# 4          South      City Hotel        8/31/2016          9/1/2016  ...
#
#   Meal_Type  Visted_Previously  Previous_Cancellations  Deposit_type  \
# 0        HB                 No                      No    No Deposit
# 1        FB                Yes                      No    No Deposit
# 2        FB                 No                      No    No Deposit
# 3        FB                Yes                      No    Refundable
# 4        HB                Yes                      No    No Deposit
#
#   Booking_channel Required_Car_Parking Reservation_Status Use_Promotion  \
# 0           Agent                   No            No-Show           Yes
# 1          Online                  Yes           Canceled            No
# 2          Direct                   No           Canceled           Yes
# 3          Direct                   No           Check-In           Yes
# 4          Online                  Yes           Check-In           Yes
#
#   Discount_Rate Room_Rate
# 0            15       192
# 1             0       187
# 2            10       227
# 3            25       189
# 4            10       218
#
# [5 rows x 24 columns]

# %%
train['Reservation_Status'].replace('Check-In', 1,inplace=True)
train['Reservation_Status'].replace('Canceled', 2,inplace=True)
train['Reservation_Status'].replace('No-Show', 3,inplace=True)

validate['Reservation_Status'].replace('Check-In', 1,inplace=True)
validate['Reservation_Status'].replace('Canceled', 2,inplace=True)
validate['Reservation_Status'].replace('No-Show', 3,inplace=True)

# %%
train['Income'].replace('<25K', 1,inplace=True)
train['Income'].replace('25K --50K', 2,inplace=True)
train['Income'].replace('50K -- 100K', 3,inplace=True)
train['Income'].replace('>100K', 4,inplace=True)

validate['Income'].replace('<25K', 1,inplace=True)
validate['Income'].replace('25K --50K', 2,inplace=True)
validate['Income'].replace('50K -- 100K', 3,inplace=True)
validate['Income'].replace('>100K', 4,inplace=True)

# %%
train['Meal_Type'].replace('BB', 1,inplace=True)
train['Meal_Type'].replace('HB', 2,inplace=True)
train['Meal_Type'].replace('FB', 3,inplace=True)

validate['Meal_Type'].replace('BB', 1,inplace=True)
validate['Meal_Type'].replace('HB', 2,inplace=True)
validate['Meal_Type'].replace('FB', 3,inplace=True)

# %% [markdown]
# ### Feature Engineering

# %%
train['checkin_month'] = pd.DatetimeIndex(train['Expected_checkin']).month
train['checkout_month'] = pd.DatetimeIndex(train['Expected_checkout']).month
train['booking_month'] = pd.DatetimeIndex(train['Booking_date']).month

# %%
validate['checkin_month'] = pd.DatetimeIndex(validate['Expected_checkin']).month
validate['checkout_month'] = pd.DatetimeIndex(validate['Expected_checkout']).month
validate['booking_month'] = pd.DatetimeIndex(validate['Booking_date']).month

# %%
train['Expected_checkin'] = pd.to_datetime(train['Expected_checkin'])
validate['Expected_checkin'] = pd.to_datetime(validate['Expected_checkin'])

train['Expected_checkout'] = pd.to_datetime(train['Expected_checkout'])
validate['Expected_checkout'] = pd.to_datetime(validate['Expected_checkout'])

train['Booking_date'] = pd.to_datetime(train['Booking_date'])
validate['Booking_date'] = pd.to_datetime(validate['Booking_date'])

# %%
train['staying_days'] = (train['Expected_checkout']-train['Expected_checkin']).dt.days
validate['staying_days'] = (validate['Expected_checkout']-validate['Expected_checkin']).dt.days

# %%
train['Dependants']=train['Adults']+train['Children']+train['Babies']
validate['Dependants'] = validate['Adults']+validate['Children']+validate['Babies']

# %%
train['Dependants_without_babies']=train['Adults']+train['Children']
validate['Dependants_without_babies'] = validate['Adults']+validate['Children']

# %%
train['days_until_check_in']=(train['Expected_checkin']-train['Booking_date']).dt.days
validate['days_until_check_in']=(validate['Expected_checkin']-validate['Booking_date']).dt.days

# %% [markdown]
# ## Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

min_max_scaler = MinMaxScaler()
train[["days_until_check_in"]] = min_max_scaler.fit_transform(train[["days_until_check_in"]])
train[["staying_days"]] = min_max_scaler.fit_transform(train[["staying_days"]])

validate[["days_until_check_in"]] = min_max_scaler.fit_transform(validate[["days_until_check_in"]])
validate[["staying_days"]] = min_max_scaler.fit_transform(validate[["staying_days"]])
#print(train["days_until_check_in"])

# %%
#Copies of originals
train_original=train.copy()
validate_original=validate.copy()
train.head()
# Out:
#    Reservation-id Gender  Age         Ethnicity Educational_Level  Income  \
# 0        39428300      F   40            Latino              Grad       1
# 1        77491756      F   49            Latino        Mid-School       3
# 2        73747291      F   42         caucasian              Grad       1
# 3        67301739      M   25  African American           College       4
# 4        77222321      F   62            Latino       High-School       2
#
#   Country_region      Hotel_Type Expected_checkin Expected_checkout  ...  \
# 0          North      City Hotel       2015-07-01        2015-07-02  ...
# 1           East      City Hotel       2015-07-01        2015-07-02  ...
# 2           East      City Hotel       2015-07-02        2015-07-06  ...
# 3          South  Airport Hotels       2015-07-02        2015-07-03  ...
# 4           East          Resort       2015-07-03        2015-07-04  ...
#
#   Use_Promotion  Discount_Rate  Room_Rate  checkin_month  checkout_month  \
# 0           Yes             10        218              7               7
# 1            No              0        185              7               7
# 2            No              0        119              7               7
# 3           Yes              5        144              7               7
# 4           Yes             10        242              7               7
#
#   booking_month staying_days Dependants Dependants_without_babies  \
# 0             5          0.0          4                         4
# 1             5          0.0          6                         6
# 2             6          1.0          6                         6
# 3             6          0.0          7                         7
# 4             6          0.0          2                         2
#
#   days_until_check_in
# 0            0.063202
# 1            0.056180
# 2            0.009831
# 3            0.022472
# 4            0.023876
#
# [5 rows x 31 columns]

# %%
train.drop(['Expected_checkin', 'Expected_checkout','Booking_date', 'Adults', 'Children', 'Babies'], axis='columns', inplace=True)
validate.drop(['Expected_checkin', 'Expected_checkout','Booking_date', 'Adults', 'Children', 'Babies'], axis='columns', inplace=True)

# %%
train.head()
# Out:
#    Reservation-id Gender  Age         Ethnicity Educational_Level  Income  \
# 0        39428300      F   40            Latino              Grad       1
# 1        77491756      F   49            Latino        Mid-School       3
# 2        73747291      F   42         caucasian              Grad       1
# 3        67301739      M   25  African American           College       4
# 4        77222321      F   62            Latino       High-School       2
#
#   Country_region      Hotel_Type  Meal_Type Visted_Previously  ...  \
# 0          North      City Hotel          1                No  ...
# 1           East      City Hotel          1                No  ...
# 2           East      City Hotel          1                No  ...
# 3          South  Airport Hotels          1                No  ...
# 4           East          Resort          1                No  ...
#
#   Use_Promotion Discount_Rate Room_Rate checkin_month  checkout_month  \
# 0           Yes            10       218             7               7
# 1            No             0       185             7               7
# 2            No             0       119             7               7
# 3           Yes             5       144             7               7
# 4           Yes            10       242             7               7
#
#   booking_month  staying_days  Dependants  Dependants_without_babies  \
# 0             5           0.0           4                          4
# 1             5           0.0           6                          6
# 2             6           1.0           6                          6
# 3             6           0.0           7                          7
# 4             6           0.0           2                          2
#
#    days_until_check_in
# 0             0.063202
# 1             0.056180
# 2             0.009831
# 3             0.022472
# 4             0.023876
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Modeling

# %%
x_t= train.drop('Reservation_Status',1)
y_t= train.Reservation_Status

# %%
x_v = validate.drop('Reservation_Status',1)
y_v= validate.Reservation_Status

# %%
x_t = pd.get_dummies(x_t)
x_v = pd.get_dummies(x_v)
x_t.head()
# Out:
#    Reservation-id  Age  Income  Meal_Type  Discount_Rate  Room_Rate  \
# 0        39428300   40       1          1             10        218
# 1        77491756   49       3          1              0        185
# 2        73747291   42       1          1              0        119
# 3        67301739   25       4          1              5        144
# 4        77222321   62       2          1             10        242
#
#    checkin_month  checkout_month  booking_month  staying_days  ...  \
# 0              7               7              5           0.0  ...
# 1              7               7              5           0.0  ...
# 2              7               7              6           1.0  ...
# 3              7               7              6           0.0  ...
# 4              7               7              6           0.0  ...
#
#    Deposit_type_No Deposit  Deposit_type_Non-Refundable  \
# 0                        1                            0
# 1                        0                            0
# 2                        1                            0
# 3                        0                            0
# 4                        1                            0
#
#    Deposit_type_Refundable  Booking_channel_Agent  Booking_channel_Direct  \
# 0                        0                      0                       0
# 1                        1                      0                       0
# 2                        0                      0                       0
# 3                        1                      1                       0
# 4                        0                      0                       1
#
#    Booking_channel_Online  Required_Car_Parking_No  Required_Car_Parking_Yes  \
# 0                       1                        0                         1
# 1                       1                        0                         1
# 2                       1                        0                         1
# 3                       0                        0                         1
# 4                       0                        1                         0
#
#    Use_Promotion_No  Use_Promotion_Yes
# 0                 0                  1
# 1                 1                  0
# 2                 1                  0
# 3                 0                  1
# 4                 0                  1
#
# [5 rows x 44 columns]

# %%
model = AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=2),
    n_estimators=600,
    learning_rate=1)

# %%
model.fit(x_t, y_t)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#                    base_estimator=DecisionTreeClassifier(class_weight=None,
#                                                          criterion='gini',
#                                                          max_depth=2,
#                                                          max_features=None,
#                                                          max_leaf_nodes=None,
#                                                          min_impurity_decrease=0.0,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=1,
#                                                          min_samples_split=2,
#                                                          min_weight_fraction_leaf=0.0,
#                                                          presort=False,
#                                                          random_state=None,
#                                                          splitter='best'),
#                    learning_rate=1, n_estimators=600, random_state=None)

# %%
pred_v = model.predict(x_v)
validate_original['Predicted']=pred_v

# %%
df = pd.DataFrame() 

# append columns to an empty DataFrame 
df['Reservation-id'] = validate['Reservation-id']
df['actual'] = validate['Reservation_Status']
df['Reservation_Status_Pred'] =pred_v

# %%
df.head()
# Out:
#    Reservation-id  actual  Reservation_Status_Pred
# 0        45716350       3                        1
# 1        88857401       2                        1
# 2        16074440       2                        1
# 3        10992124       1                        1
# 4        15934351       1                        1

# %%
df['Reservation_Status_Pred'].unique()
# Out:
# array([1, 3, 2], dtype=int64)

# %%
accuracy_score(y_v,pred_v)
# Out:
# 0.5853037468170244

# %% [markdown]
# ## Prediction

# %%
test=pd.read_csv('F:\Data Storm 2.0\Dataset\Hotel-A-test.csv')

# %%
test['Meal_Type'].replace('BB', 1,inplace=True)
test['Meal_Type'].replace('HB', 2,inplace=True)
test['Meal_Type'].replace('FB', 3,inplace=True)

# %%
test['checkin_month'] = pd.DatetimeIndex(test['Expected_checkin']).month
test['checkout_month']=pd.DatetimeIndex(test['Expected_checkout']).month
test['booking_month']=pd.DatetimeIndex(test['Booking_date']).month

# %%
test['Expected_checkin'] = pd.to_datetime(test['Expected_checkin'])
test['Expected_checkout'] = pd.to_datetime(test['Expected_checkout'])
test['Booking_date'] = pd.to_datetime(test['Booking_date'])

# %%
test['days_until_check_in']=(test['Expected_checkin']-test['Booking_date']).dt.days

# %%
test['staying_days'] = (test['Expected_checkout']-test['Expected_checkin']).dt.days

# %%
test['Dependants']=test['Adults']+test['Children']+test['Babies']

# %%
test['Dependants_without_babies']=test['Adults']+test['Children']

# %%
min_max_scaler = MinMaxScaler()
test[["days_until_check_in"]] = min_max_scaler.fit_transform(test[["days_until_check_in"]])
test[["staying_days"]] = min_max_scaler.fit_transform(test[["staying_days"]])

# %%
test.drop(['Expected_checkin', 'Expected_checkout','Booking_date', 'Adults', 'Children', 'Babies'], axis='columns', inplace=True)

# %%
test.head()
# Out:
#    Reservation-id  Age  Meal_Type  Discount_Rate  Room_Rate  checkin_month  \
# 0        62931593   52          2             10        153             11
# 1        70586099   47          3              0        210             11
# 2         4230648   28          1              5        117              4
# 3        25192322   65          3             10        107             11
# 4        80931528   45          1              0        119             11
#
#    checkout_month  booking_month  days_until_check_in  staying_days  ...  \
# 0              11             10             0.110619      0.000000  ...
# 1              11              8             0.477876      0.000000  ...
# 2               5              4             0.106195      0.666667  ...
# 3              11              5             0.823009      0.333333  ...
# 4              11             10             0.097345      0.333333  ...
#
#    Deposit_type_No Deposit  Deposit_type_Non-Refundable  \
# 0                        1                            0
# 1                        1                            0
# 2                        1                            0
# 3                        1                            0
# 4                        0                            0
#
#    Deposit_type_Refundable  Booking_channel_Agent  Booking_channel_Direct  \
# 0                        0                      0                       1
# 1                        0                      0                       0
# 2                        0                      1                       0
# 3                        0                      0                       0
# 4                        1                      1                       0
#
#    Booking_channel_Online  Required_Car_Parking_No  Required_Car_Parking_Yes  \
# 0                       0                        0                         1
# 1                       1                        1                         0
# 2                       0                        1                         0
# 3                       1                        0                         1
# 4                       0                        1                         0
#
#    Use_Promotion_No  Use_Promotion_Yes
# 0                 0                  1
# 1                 1                  0
# 2                 0                  1
# 3                 0                  1
# 4                 1                  0
#
# [5 rows x 47 columns]

# %%
test = pd.get_dummies(test)

# %%
pred_test = model.predict(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-7b250e5eaa7d> in <module>
# ----> 1 pred_test = model.predict(test)
#
# c:\users\tharushi samara\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\weight_boosting.py in predict(self, X)
#     615         X = self._validate_data(X)
#     616
# --> 617         pred = self.decision_function(X)
#     618
#     619         if self.n_classes_ == 2:
#
# c:\users\tharushi samara\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\weight_boosting.py in decision_function(self, X)
#     685             # The weights are all 1. for SAMME.R
#     686             pred = sum(_samme_proba(estimator, n_classes, X)
# --> 687                        for estimator in self.estimators_)
#     688         else:  # self.algorithm == "SAMME"
#     689             pred = sum((estimator.predict(X) == classes).T * w
#
# c:\users\tharushi samara\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\weight_boosting.py in <genexpr>(.0)
#     685             # The weights are all 1. for SAMME.R
#     686             pred = sum(_samme_proba(estimator, n_classes, X)
# --> 687                        for estimator in self.estimators_)
#     688         else:  # self.algorithm == "SAMME"
#     689             pred = sum((estimator.predict(X) == classes).T * w
#
# c:\users\tharushi samara\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\weight_boosting.py in _samme_proba(estimator, n_classes, X)
#     278
#     279     """
# --> 280     proba = estimator.predict_proba(X)
#     281
#     282     # Displace zero probabilities so the log is defined.
#
# c:\users\tharushi samara\appdata\local\programs\python\python37\lib\site-packages\sklearn\tree\tree.py in predict_proba(self, X, check_input)
#     845         """
#     846         check_is_fitted(self, 'tree_')
# --> 847         X = self._validate_X_predict(X, check_input)
#     848         proba = self.tree_.predict(X)
#     849
#
# c:\users\tharushi samara\appdata\local\programs\python\python37\lib\site-packages\sklearn\tree\tree.py in _validate_X_predict(self, X, check_input)
#     400                              "match the input. Model n_features is %s and "
#     401                              "input n_features is %s "
# --> 402                              % (self.n_features_, n_features))
#     403
#     404         return X
#
# ValueError: Number of features of the model must match the input. Model n_features is 44 and input n_features is 47

# %%
submission=pd.DataFrame()
submission['Reservation-id']=test_original['Reservation-id']
submission['Reservation_Status']=pred_test

# %%
print(set(list(pred_test)))

# %%
#submission.to_csv('Submission_1.csv',index=False)
